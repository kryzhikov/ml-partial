# %% [markdown]
# # Примеры построенных прогнозов

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# Пример 1. Регрессия на двух признаках

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt

model = LinearRegression(fit_intercept=True)
X = np.ones((200,3))
X[:,1]*=np.random.normal(0,1,(200,))
X[:,2]*=np.random.normal(0,1,(200,))
y = X @ np.array([50,14,-7]) + np.random.normal(0,5,(200,))

model.fit(X[:,[1,2]], y)

coefs = model.coef_
const = model.intercept_

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = px.scatter_3d(np.concatenate((X,y.reshape(-1,1)), axis=1),  x=1, y=2, z=3,
                    size_max=5, opacity=0.5, color_discrete_sequence=['red'])

# tight layout
fig.update_layout(margin=dict(l=10, r=100, b=100, t=10))

x1 = np.linspace(-3, 3, 30)
y1 = np.linspace(-3, 3, 30)
xx, yy = np.meshgrid(x1, y1)
z = np.c_[xx.ravel(), yy.ravel()] @ np.array(coefs[0:2]) + const 

# transpose
z = z.reshape(xx.shape)
fig.add_traces(go.Surface(x=x1, y=y1, z=z, showscale=False,
                          opacity=0.3, colorscale=[[0, 'rgb(0,0,255)'], [1, 'rgb(0,0,255)']]))
fig.show()
# Out:
# <div>                            <div id="85b93b24-bdec-404f-b8ef-7631216093b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85b93b24-bdec-404f-b8ef-7631216093b7")) {                    Plotly.newPlot(                        "85b93b24-bdec-404f-b8ef-7631216093b7",                        [{"hovertemplate":"1=%{x}<br>2=%{y}<br>3=%{z}<extra></extra>","legendgroup":"","marker":{"color":"red","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-0.5101009901428405,0.7168552309450761,0.6012050165007324,-0.23036101835289108,0.15273837626400188,0.7979778894192898,-1.1304961499150508,0.11409561476375625,-1.3910052092394054,0.3310981984507247,0.9031176668592271,-0.5694751370495112,0.015824651128762468,-0.4601372037229006,0.08381591621254862,1.1254487979994592,-0.8843126966874318,-1.458813232805769,-0.916263909205307,0.8929293287365717,-0.9450382664910327,0.3371176122941393,0.0738169715895036,-0.5370814065682836,0.971097650159337,-0.19412888474486098,-0.06837139525057419,-0.042734460022197045,1.507872335460088,1.7544637937195235,-0.2443528847990176,0.7401606737257604,-0.01202711008971953,-1.0078189099494328,-0.4207843268078223,-1.3755502980552778,-0.15854627252811246,-1.1546624411637727,0.6573681273413021,-0.9360006551216598,0.3584491598611076,1.8884357854985916,1.8073231637337432,1.0923908652200436,-0.15808786488681947,0.18541355666686826,0.9137925244249321,0.7478447014611126,1.1183303730227134,-0.48436985934016025,-0.8476497400468067,-0.40314823908027625,-0.6276454601035846,-0.22502740245838795,-1.3040894369057996,0.41350860875410467,-1.3932963920313797,-0.302305175482171,-1.6231748846604994,-0.5125809423644393,0.23523579122289137,-1.1415132499680578,-1.0805856171324493,-0.34744478660722544,0.12579772743018738,0.2259306233469371,-0.4112593318138491,0.6876743947454385,-1.1109351820383953,-0.1826802217090012,-1.4929402002049748,1.1410829536888298,-0.14543840261016702,0.5529553481792508,0.43185893697748756,-0.2864513413088631,1.0393275560783841,0.8086488565892354,0.6893152349777508,-0.5629749907846664,0.10893079708694046,0.7604273272103025,0.36481890509473036,-0.1181552496561546,0.25895881567004186,-0.46314447646418233,-0.4601862039326409,-0.09537199202995772,0.14569346982771542,-0.5450860128542135,1.228647627298132,0.4211475890922262,-0.9689931047956503,-0.8667082433309812,0.11569815933440418,-0.2759713651815787,-0.3567692334537925,1.8827862872824002,0.32683680784531755,-1.2563329563913015,0.7256613441120361,-1.7885888609298308,-0.8112935414167084,-0.9359429001456221,-1.6197455766947364,1.351690054602842,0.4544425468255826,1.4863689959417103,-1.9394973954879702,0.04142395414334827,0.894078795770514,-1.0846701447336125,-1.1651385752890708,0.9972143148557623,0.9435948899567859,-0.6669407494393582,0.06391527220516913,-0.09184708141969779,-0.780834394261942,-0.2865010709290698,0.2900238059401421,-0.5170087792844922,0.18536322578328004,-0.8120618592629365,-1.8146969420677153,1.3571422940553686,-1.0462514983182163,-1.0713544544015352,-0.1320070736610476,-1.0646501963107058,0.7172778407590416,0.8848794380668927,0.8347592630569858,-1.6613137721907868e-05,-0.8080928107302912,0.6733479199648186,0.6497334866423606,0.44776175107702115,0.014993914755291615,0.7703931365345196,0.26866081653081547,-1.1541298457536298,-1.3868450465350053,-0.7083034948649741,-1.704736592859711,0.365718571297439,0.21602713761113368,-1.275135185673248,-0.1362444847577449,0.5823360301334055,-0.3753946679392713,0.8453955737386207,-2.297639689615373,0.28972927815109706,-0.4456113606634704,-0.764894725282053,0.5933389955692374,1.0068284847005013,1.4804892628450892,-0.35945683960052116,0.15619073461644367,-0.8192642404868433,-0.2750345907575243,0.02828436762783651,0.19482232173384054,0.096939637 ...

# %% [markdown]
# Пример 2. Бинарная классификация

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import seaborn as sns
import pickle
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

plt.rcParams["figure.figsize"] = (10,10)

with open('sem5_data_example.pkl', 'rb') as file:
    X, y = pickle.load(file)
    
def plot_data_points(X, labels, xlim, ylim):
    g = sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=labels)
    g.set(xlim=xlim, ylim=ylim)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid()

def plot_knn_bound(X, y, scaler=None, n_neighbors=10, xlim=(-15, 15), ylim=(-20, 20)):
    # step size in the mesh
    h = 0.05

    # Create color maps
    cmap_light = ListedColormap(['C0', 'orange', 'cyan', 'green'][:np.unique(y).shape[0]])
    cmap_bold = ['C0', 'orange', 'c', 'darkgreen'][:np.unique(y).shape[0]]

    x_min, x_max = xlim
    y_min, y_max = ylim
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    grid = np.c_[xx.ravel(), yy.ravel()]
    
    X_scaled = X # if scaler is None
    if scaler is not None:
        grid = scaler.transform(grid)
        X_scaled = scaler.transform(X)

    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, algorithm='brute')
    clf.fit(X_scaled, y)

    Z = clf.predict(grid)

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=cmap_light)

    #     # Plot also the training points
    sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y,
                    palette=cmap_bold, alpha=1.0, edgecolor="black")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid()
    plt.show()
    
StandardNormalizer = StandardScaler()

StandardNormalizer.fit(X)

plot_knn_bound(X, y, StandardNormalizer, n_neighbors=10)

# %% [markdown]
# Пример 3. Кластеризация

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(20, 20))

n_samples = 1500
random_state = 170

X_varied, y_varied = make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_varied)

plt.subplot(223)
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred)
plt.title("Clustering example")
plt.grid()

plt.show()

# %% [markdown]
# # Пишем градиентный спуск

# %%
import matplotlib

random_seed = 43
n_features = 2
n_objects = 300
batch_size = 10
num_steps = 50
np.random.seed(random_seed)

# Генерим истинные веса
w_true = np.random.normal(size=(n_features, ))

# Под веса создаем признаки
X = np.random.uniform(-5, 5, (n_objects, n_features))

X *= (np.arange(n_features) * 2 + 1)[np.newaxis, :] 

# Создаем таргет
Y = X.dot(w_true) + np.random.normal(0, 1, n_objects)

# %% [markdown]
# $\nabla MSE = -\frac{2}{n}X^T(Y - Xw)$

# %%
# Пишем градиентный спуск
np.random.seed(random_seed)
w_0 = np.random.uniform(-2, 2, n_features)-0.5
w = w_0.copy()
w_list = [w.copy()]
learning_rate = 1e-2

for i in range(num_steps):
    w -= #YOUR CODE
    w_list.append(w.copy())
    
w_list = np.array(w_list)

# %%
matplotlib.rcParams.update({'font.size': 16})

# Визуализируем градиентный спуск
A, B = np.meshgrid(np.linspace(-2, 2, 100), np.linspace(-2, 2, 100))

levels = np.empty_like(A)
for i in range(A.shape[0]):
    for j in range(A.shape[1]):
        w_tmp = np.array([A[i, j], B[i, j]])
        levels[i, j] = np.mean(np.power(np.dot(X, w_tmp) - Y, 2))

plt.figure(figsize=(13, 9))
plt.title('GD trajectory')
plt.xlabel('$w_1$')
plt.ylabel('$w_2$')
plt.xlim(w_list[:, 0].min() - 0.1, w_list[:, 0].max() + 0.1)
plt.ylim(w_list[:, 1].min() - 0.1, w_list[:, 1].max() + 0.1)
plt.gca().set_aspect('equal')

CS = plt.contour(A, B, levels, levels=np.logspace(0, 2, num=15), cmap=plt.cm.rainbow_r)
CB = plt.colorbar(CS, shrink=0.8, extend='both')

plt.scatter(w_true[0], w_true[1], c='r')
plt.scatter(w_list[:, 0], w_list[:, 1])
plt.plot(w_list[:, 0], w_list[:, 1])

plt.show()

# %% [markdown]
# # Пишем стохастический градиентный спуск

# %%
np.random.seed(random_seed)
w = w_0.copy()
w_list = [w.copy()]
lr = 1e-2
batch_size = 25
num_steps = 25

for i in range(num_steps):
    sample_indices = np.random.randint(n_objects, size=batch_size)
    w -= #YOUR CODE 
    w_list.append(w.copy())

w_list = np.array(w_list)

# %%
A, B = np.meshgrid(np.linspace(-2, 2, 100), np.linspace(-2, 2, 100))

levels = np.empty_like(A)
for i in range(A.shape[0]):
    for j in range(A.shape[1]):
        w_tmp = np.array([A[i, j], B[i, j]])
        levels[i, j] = np.mean(np.power(np.dot(X, w_tmp) - Y, 2))

plt.figure(figsize=(13, 9))
plt.title('SGD trajectory')
plt.xlabel(r'$w_1$')
plt.ylabel(r'$w_2$')
plt.xlim((w_list[:, 0].min() - 0.1, w_list[:, 0].max() + 0.1))
plt.ylim((w_list[:, 1].min() - 0.1, w_list[:, 1].max() + 0.1))
plt.gca().set_aspect('equal')

# visualize the level set
CS = plt.contour(A, B, levels, levels=np.logspace(0, 2, num=40), cmap=plt.cm.rainbow_r)
CB = plt.colorbar(CS, shrink=0.8, extend='both')

# visualize trajectory
plt.scatter(w_true[0], w_true[1], c='r')
plt.scatter(w_list[:, 0], w_list[:, 1])
plt.plot(w_list[:, 0], w_list[:, 1])

plt.show()

# %% [markdown]
# # Реализация линейной регресии

# %% [markdown]
# Реализация

# %%
from sklearn.base import BaseEstimator, RegressorMixin

class LinearRergessionSGD(BaseEstimator, RegressorMixin):
    
    def __init__(self, batch_size=25, num_steps=350, lr=1e-2):


    def fit(self, X, Y):


    def predict(self, X):

# %% [markdown]
# Сравнение

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

#Генерация данных для тестирования
n_features = 700
n_objects = 100000
num_steps = 150

w_true = np.random.uniform(-2, 2, (n_features, 1))

X = np.random.uniform(-100, 100, (n_objects, n_features)) * np.arange(n_features)
Y = X.dot(w_true) + np.random.normal(0, 10, (n_objects, 1))

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y)

# %%
scaler = StandardScaler()
scaler.fit(x_train)
x_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
own_model = LinearRergessionSGD().fit(x_scaled, y_train)
y_pred = own_model.predict(x_test_scaled)
print(f'R2: {own_model.score(x_test_scaled, y_test)}')

sklearn_model = LinearRegression().fit(x_scaled, y_train)
print(f'R2: {sklearn_model.score(x_test_scaled, y_test)}')
# Out:
# R2: 0.9999059715616564
# R2: 0.9999999998022979
