# %%
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
X, y = make_blobs(n_features=2, centers=2, random_state=42)

# %% [markdown]
# Нормализуем данные:

# %%
X[:, 0] = (X[:, 0] - X[:, 0].mean())/X[:, 0].std()
X[:, 1] = (X[:, 1] - X[:, 1].mean())/X[:, 1].std()

# %%
plt.scatter(X[y==0][:,0], X[y==0][:,1])
plt.scatter(X[y==1][:,0], X[y==1][:,1])
plt.xlabel('X1')
plt.ylabel('X2')
plt.grid()

# %% [markdown]
# Добавим столбец свободных членов:

# %%
X = np.append(X, np.ones(100).reshape(-1, 1), axis=1)

# %% [markdown]
# # Логистическая регрессия

# %% [markdown]
# Конечным результатом задачи классификации является разбиение множества объектов на классы. Давайте усложним задачу и будем предсказывать не конкретные классы, а вероятности принадлежать им, например, для бинарной классификации мы будем предсказывать одно число, которое будет соответствовать вероятности принадлежать положительному классу. \
# Такого результата можно достичь, если мы будем строить линейную регрессию над некоторыми признаками, а затем её результат переводить в отрезок $[0;1]$. В этом нам поможет сигмоидная функция, которая имеет вид:
# <p style="text-align: center;"> $f(z) = \dfrac{1}{1 + e^{-z}}$ </p>
#
# ![sigmoid.webp](https://cmertin.github.io/images/2016/11/11_17-Loan_Approvals/Sigmoid_Function.png)
# <p style="text-align: center;"></p>
#
# Моделью логистической регрессии назовём функцию от весов и объекта вида:
#
# <p style="text-align: center;"> $a(w, x) = \dfrac{1}{1 + e^{-w_0 - w_1x_1 + ... + w_mx_m}}$ </p>
#
# Обучение данной модели происходит за счет кросс-энтропийной или логистическая функции потерь :
# <p style="text-align: center;"> $-\sum\limits_{i=1}^{n}(y_ilog(a_i) + (1 - y_i)log(1 - a_i))$ </p>
# где $a_i = a(w, x_i)$
#
# #### Задание №1. Выведите шаг градиентного спуска для логистической функции потерь (приложить фото)

# %%
from IPython.display import Image
Image(filename='Grad.jpg')

# %% [markdown]
# #### Задание №2. Напишите собственную логистическую регрессию

# %%
def sigmoid(X, W):
    return 1/(1+np.exp(-(X @ W)))

# %%
def grad(X, y, y_pred):
    return - (X.T @ (y - y_pred)) / X.shape[0]

# %%
class MyLogRegression:
    
    def __init__(self, W=[]):
        self.W = W
    
    def fit(self, X, y, lr=0.01, steps=10000):
        self.W = np.random.normal(0, 1, X.shape[1])
        for i in range(steps):
            y_pred = sigmoid(X, self.W)
            g = grad(X, y, y_pred)
            self.W = self.W - lr*g
    
    def predict(self, X):
        res = sigmoid(X, self.W)
        res[res>=0.5] = 1
        res[res<0.5] = 0
        return res

# %% [markdown]
# #### Задание №3. Сравните свою логистическую регрессию с аналогичной моделью из sklearn на сгенерированном датасете, опираясь на Accuracy. Баллы за задание: 10 - Accuracy > 99, 5 - Accuracy > 85, 0 - иначе

# %%
myReg = MyLogRegression()
myReg.fit(X, y)
reg = LogisticRegression(fit_intercept=False).fit(X, y)

# %%
def sigmoid_m(X, Y, W):
    return 1/(1+np.exp(-(X*W[0] + Y*W[1] + W[2])))

# %%
x_m = np.linspace(-2, 2, 100)
y_m = np.linspace(-2, 2, 100)
X_m, Y_m = np.meshgrid(x_m, y_m)
Z_m = sigmoid_m(X_m, Y_m, myReg.W)

# %%
plt.pcolormesh(X_m, Y_m, Z_m, cmap='gray', shading='auto')
plt.scatter(X[y==0][:,0], X[y==0][:,1], s=80, c='black', edgecolors='red')
plt.scatter(X[y==1][:,0], X[y==1][:,1], s=80, c='white', edgecolors='red');
plt.title('Разделяющая логистической модели MyReg');

# %% [markdown]
# Accuracy score моей модели:

# %%
accuracy_score(y, myReg.predict(X))
# Out:
# 1.0

# %% [markdown]
# Веса моей модели:

# %%
myReg.W
# Out:
# array([ 2.95875065, -2.60998892,  0.03397256])

# %%
x_m = np.linspace(-2, 2, 100)
y_m = np.linspace(-2, 2, 100)
X_m, Y_m = np.meshgrid(x_m, y_m)
Z_m = sigmoid_m(X_m, Y_m, reg.coef_[0])

# %%
plt.pcolormesh(X_m, Y_m, Z_m, cmap='gray', shading='auto')
plt.scatter(X[y==0][:,0], X[y==0][:,1], s=80, c='black', edgecolors='red')
plt.scatter(X[y==1][:,0], X[y==1][:,1], s=80, c='white', edgecolors='red');
plt.title('Разделяющая поверхность логистической модели Sklearn');

# %% [markdown]
# Accuracy score Sklearn LogisticRegression

# %%
accuracy_score(y, reg.predict(X))
# Out:
# 1.0

# %% [markdown]
# Веса модели Sklearn:

# %%
reg.coef_[0]
# Out:
# array([ 2.11977248, -1.95674119,  0.004464  ])
